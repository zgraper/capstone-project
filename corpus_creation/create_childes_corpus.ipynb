# %% [markdown]
# ## **CHILDES IPA Corpus Construction**
#
# Zane Graper
#
# Capstone
#
# This notebook builds a high-quality, multi-view IPA corpus for fine-tuning the T5-small IPA-to-Text model.
# It uses the phonemetransformers/IPA-CHILDES dataset and generates three aligned versions of each utterance:
#
# * Raw IPA (canonical)
#
# * Boundary-augmented IPA
#
# * Rule-augmented IPA (phonological correction layer)
#
# Each IPA representation is paired with the same canonical text transcript, enabling robust training across different phoneme conditions.
#
# ### **1. Environment Setup**
#
# Mounts Google Drive for storage.
#
# Installs required libraries:
#
# * `datasets` (Hugging Face Datasets)
#
# * `Pandas`
#
# * `regex`, `re`
#
# * `transformers`
#
# Creates a dedicated output directory under:
# MyDrive/Capstone/Corpus/ipa_childes_finetune/.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install datasets pandas --quiet

import os
from datasets import load_dataset
import pandas as pd

# Define output directory in Drive
output_dir = "/content/drive/MyDrive/Capstone/Corpus/ipa_childes"
os.makedirs(output_dir, exist_ok=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **2. Load the IPA-CHILDES Dataset**
#
# The notebook loads:
#
# ```
# dataset = load_dataset("phonemetransformers/IPA-CHILDES", "EnglishNA", split="train")
# ```
# This dataset contains:
#
# * IPA transcriptions
#
# * Raw gloss text
#
# * Child / adult metadata
#
# * Word and morpheme counts
#
# The notebook optionally includes both child and adult lines to help the model generalize better.

# %%
# ---------------------------------
# Load CHILDES dataset
# ---------------------------------
dataset = load_dataset("phonemetransformers/IPA-CHILDES", "EnglishNA", split="train")
df = dataset.to_pandas()

# Keep BOTH adult + child speech (better generalization)
# If you want child only, uncomment below:
# df = df[df["is_child"] == True]

# Minimum utterance length
min_words = 3
df["word_count"] = df["processed_gloss"].str.split().apply(len)
df = df[df["word_count"] >= min_words]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# Eng-NA/processed.csv:   0%|          | 0.00/856M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2564614 [00:00<?, ? examples/s]

# %% [markdown]
# ### **3. Filtering and Cleaning**
#
# The notebook applies several preprocessing steps:
#
# 1. Min utterance length filter - Removes short utterances (configurable: min_words).
#
# 2. IPA cleaning - Removes:
#
#    * `WORD_BOUNDARY`
#
#    * extraneous punctuation
#
#    * excessive whitespace
#
# 3. Text cleaning - Converts to lowercase and strips trailing whitespace.
#
# 4. Duplicate removal - Ensures one IPA ↔ Text mapping per unique utterance.
#
# The result is a clean paired dataset with columns:
#
# * `IPA_raw`
#
# * `ext`

# %%
# ---------------------------------
# Cleaning functions
# ---------------------------------
import re

def clean_ipa(text):
    if not isinstance(text, str): return ""
    text = re.sub(r"WORD_BOUNDARY", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def clean_text(text):
    if not isinstance(text, str): return ""
    return text.lower().strip()

df["IPA_raw"] = df["ipa_transcription"].apply(clean_ipa)
df["Text"] = df["processed_gloss"].apply(clean_text)

df = df[(df["IPA_raw"] != "") & (df["Text"] != "")]
df = df.drop_duplicates(subset=["IPA_raw", "Text"]).reset_index(drop=True)

# %% [markdown]
# ### **4. Boundary Augmentation**
#
# Generates IPA_boundary, a version of IPA with inserted boundary markers | based on phonotactic heuristics:
#
# * Inserts a boundary between:
#
#    * vowel/nasal → voiceless stop
#
# This helps the model identify word boundaries that may be missing in child IPA.
#
# The rule used is conservative, designed to avoid over-segmentation.

# %%
# ---------------------------------
# Boundary Augmentation
# ---------------------------------
def approximate_boundaries(ipa_seq):
    tokens = ipa_seq.split()
    out = []
    for i, tok in enumerate(tokens[:-1]):
        nxt = tokens[i+1]
        out.append(tok)
        if tok in ["a","e","i","o","u","æ","ʌ","ɪ","ʊ","ə","n","m"] and nxt in ["p","t","k"]:
            out.append("|")
    out.append(tokens[-1])
    return " ".join(out)

df["IPA_boundary"] = df["IPA_raw"].apply(approximate_boundaries)

# %% [markdown]
# ### **5. Rule-Based IPA Correction**
#
# A refined phonological “correction layer” is applied to produce IPA_rule using:
#
# * Final consonant restoration
#
# * Liquid restoration (ɹ, l)
#
# * Nasal restoration (n, m)
#
# * s-cluster restoration
#
# * Weak vowel (ə) insertion
#
# All rules are lexicon-gated, meaning they only apply when the resulting IPA sequence corresponds to an actual word in the CHILDES-derived lexicon.
#
# This version is intended to help the model:
#
# * recover missing segments
#
# * learn from corrected pronunciations
#
# * normalize child speech IPA

# %%
# ---------------------------------
# Load lexicon (you already generated this)
# ---------------------------------
lexicon_path = "/content/drive/MyDrive/Capstone/Corpus/lexicon/lexicon.txt"
LEXICON = set()
with open(lexicon_path) as f:
    for line in f:
        LEXICON.add(line.strip().lower())

def ipa_to_word(ipa_seq):
    """Temporary mapping: collapse phonemes to a 'word key'."""
    return ipa_seq.replace(" ", "").replace("|", "")

# %% [markdown]
# ### **6. Collapse IPA Forms**
#
# Before training, all IPA forms are collapsed to remove spaces:
# ```
# IPA_raw:       "k æ t" → "kæt"
# IPA_boundary:  "k æ | t" → "kæ|t"
# IPA_rule:      "k æ t" (corrected) → "kæt"
# ```
#
# This ensures compatibility with the tokenizer, which was trained on unsegmented phoneme strings.

# %%
# ---------------------------------
# Rule-Based Correction (v1.1 rules)
# ---------------------------------
def correct_phonemes(ipa_seq):
    seq = ipa_seq.split()
    out = seq[:]

    def lex_ok(tokens):
        return ipa_to_word("".join(tokens)) in LEXICON

    # Rule A: Final consonant restoration
    vowels = ["æ","ɪ","ʌ","ə","ɑ","oʊ","u"]
    codas = ["t","d","k","n","s","m"]
    if out and out[-1] in vowels:
        for c in codas:
            cand = out + [c]
            if lex_ok(cand):
                out = cand
                break

    # Rule B: Liquid restoration
    if out and out[-1] in ["ɑ", "ɔ", "oʊ"]:
        for liq in ["ɹ", "l"]:
            cand = out + [liq]
            if lex_ok(cand):
                out = cand
                break

    # Rule C: Nasal restoration
    if out and out[-1] in ["oʊ", "ɑ", "u"]:
        for n in ["n", "m"]:
            cand = out + [n]
            if lex_ok(cand):
                out = cand
                break

    # Rule D: s-cluster restoration
    if out and out[0] in ["p", "t", "k"]:
        cand = ["s"] + out
        if lex_ok(cand):
            out = cand

    # Rule E: Weak vowel restoration
    bad_clusters = [("b","n"), ("n","n"), ("d","m"), ("t","n")]
    for (c1,c2) in bad_clusters:
        for i in range(len(out)-1):
            if out[i] == c1 and out[i+1] == c2:
                cand = out[:i+1] + ["ə"] + out[i+1:]
                if lex_ok(cand):
                    out = cand
                    break

    return " ".join(out)

df["IPA_rule"] = df["IPA_boundary"].apply(correct_phonemes)

# %% [markdown]
# 7. Train/Validation Split
#
# A randomized 90/10 split is applied to the combined dataset.
#
# Output files saved:
# ```
# train_3view.tsv
# valid_3view.tsv
# ```
#
# Each row contains:
#
# * IPA_raw
# * IPA_boundary
# * IPA_rule
# * Text

# %%
# ---------------------------------
# Collapse for model input
# ---------------------------------
df["IPA_raw"] = df["IPA_raw"].str.replace(" ", "")
df["IPA_boundary"] = df["IPA_boundary"].str.replace(" ", "")
df["IPA_rule"] = df["IPA_rule"].str.replace(" ", "").str.replace("|","")

# %% [markdown]
# ### **8. Summary + Preview**
#
# The notebook prints:
#
# * dataset sizes
#
# * random sample rows
#
# * the first 20 corpus entries for manual inspection.
#
# Be sure to verify that:
#
# * IPA strings are valid
#
# * boundaries and corrections are reasonable
#
# * text lines look clean and aligned

# %%
# ---------------------------------
# Train/Valid split
# ---------------------------------
df = df.sample(frac=1, random_state=42)
cut = int(0.9 * len(df))
train_df, valid_df = df.iloc[:cut], df.iloc[cut:]

# Save ALL three views for training
train_df.to_csv(os.path.join(output_dir, "train_3view.tsv"), sep="\t", index=False)
valid_df.to_csv(os.path.join(output_dir, "valid_3view.tsv"), sep="\t", index=False)

print("Saved 3-view dataset:")
print("Train:", len(train_df), "rows")
print("Valid:", len(valid_df), "rows")

train_df.head(10)
# Out:
# Saved 3-view dataset:
# Train: 1033399 rows
# Valid: 114823 rows
#                                            processed_gloss  \
# 190240                            daddy needs two flashes.
# 342890                       should we show her that song?
# 293751                              lots of presents here.
# 817748             you don't know anything about broccoli?
# 25046                                    in my ska school.
# 1089846                       just pretend there's a door.
# 809100                      yeah what other kind of candy?
# 544467              and then we have to make the checkers.
# 751784   but i guess if you're not throwing up or anyth...
# 735153          maybe you should just go see what's wrong.
#
#                                          ipa_transcription  \
# 190240   d æ d i WORD_BOUNDARY n iː d z WORD_BOUNDARY t...
# 342890   ʃ ʊ d WORD_BOUNDARY w iː WORD_BOUNDARY ʃ oʊ WO...
# 293751   l ɑ t s WORD_BOUNDARY ʌ v WORD_BOUNDARY p ɹ ɛ ...
# 817748   j uː WORD_BOUNDARY d oʊ n t WORD_BOUNDARY n oʊ...
# 25046    ɪ n WORD_BOUNDARY m aɪ WORD_BOUNDARY s k ɑ WOR...
# 1089846  d̠ʒ ʌ s t WORD_BOUNDARY p ɹ ɪ t ɛ n d WORD_BOU...
# 809100   j ɛ h WORD_BOUNDARY w ʌ t WORD_BOUNDARY ʌ ð ə ...
# 544467   æ n d WORD_BOUNDARY ð ɛ n WORD_BOUNDARY w iː W...
# 751784   b ʌ t WORD_BOUNDARY aɪ WORD_BOUNDARY ɡ ɛ s WOR...
# 735153   m eɪ b iː WORD_BOUNDARY j uː WORD_BOUNDARY ʃ ʊ...
#
#                                  character_split_utterance  is_child  \
# 190240   d a d d y WORD_BOUNDARY n e e d s WORD_BOUNDAR...     False
# 342890   s h o u l d WORD_BOUNDARY w e WORD_BOUNDARY s ...     False
# 293751   l o t s WORD_BOUNDARY o f WORD_BOUNDARY p r e ...     False
# 817748   y o u WORD_BOUNDARY d o n ' t WORD_BOUNDARY k ...     False
# 25046    i n WORD_BOUNDARY m y WORD_BOUNDARY s k a WORD...     False
# 1089846  j u s t WORD_BOUNDARY p r e t e n d WORD_BOUND...     False
# 809100   y e a h WORD_BOUNDARY w h a t WORD_BOUNDARY o ...     False
# 544467   a n d WORD_BOUNDARY t h e n WORD_BOUNDARY w e ...     False
# 751784   b u t WORD_BOUNDARY i WORD_BOUNDARY g u e s s ...     False
# 735153   m a y b e WORD_BOUNDARY y o u WORD_BOUNDARY s ...     False
#
#                id                                              gloss  \
# 190240     743590                            Daddy needs two flashes
# 342890     331820                       should we show her that song
# 293751     835985                              lots_of presents here
# 817748    1546021             you don't know anything about broccoli
# 25046     2409963                                   in my ska school
# 1089846   1607475                        just pretend there's a door
# 809100    1185772                      yeah what other kind of candy
# 544467   17402128              and then we have to make the checkers
# 751784    1110285  but I guess if you're not throwing up or anything
# 735153    1158095          maybe you should just go see what's wrong
#
#                                                 stem                   type  \
# 190240                          Daddy need two flash            declarative
# 342890                  should we show her that song               question
# 293751                          lots_of present here            declarative
# 817748                                                             question
# 25046                                   in my school            declarative
# 1089846                    just pretend there a door  missing CA terminator
# 809100                 yeah what other kind of candy               question
# 544467          and then we have to make the checker            declarative
# 751784   but I guess if you not throw up or anything            declarative
# 735153       maybe you should just go see what wrong            declarative
#
#         language  num_morphemes  ...  collection_id corpus_id speaker_id  \
# 190240   eng haw              6  ...              2        43       2344
# 342890       eng              6  ...              2        35       1704
# 293751       eng              4  ...              2        45       2515
# 817748       eng    -2147483648  ...              2        52       3048
# 25046        eng              3  ...              2        71       3927
# 1089846      eng              6  ...              2        53       3126
# 809100       eng              6  ...              2        51       2724
# 544467       eng              9  ...             21       336      23488
# 751784       eng             12  ...              2        51       2754
# 735153       eng              9  ...              2        51       2767
#
#          target_child_id transcript_id  word_count  \
# 190240              2341          4205           4
# 342890              1702          3686           6
# 293751              2514          4304           4
# 817748              3047          6828           6
# 25046               3918          9459           4
# 1089846      -2147483648          6977           5
# 809100              2722          5509           6
# 544467             23487         43309           8
# 751784              2722          5240          10
# 735153              2722          5355           8
#
#                                   IPA_raw  \
# 190240                 dædiniːdztuːflæʃɪz
# 342890                 ʃʊdwiːʃoʊhɜːðætsɔŋ
# 293751                  lɑtsʌvpɹɛzəntshɪɹ
# 817748      juːdoʊntnoʊɛnɪθɪŋʌbaʊtbɹɑkəli
# 25046                       ɪnmaɪskɑskuːl
# 1089846             d̠ʒʌstpɹɪtɛndðɛɹzʌdɔɹ
# 809100             jɛhwʌtʌðəɹkaɪndʌvkændi
# 544467       ændðɛnwiːhævtəmeɪkðət̠ʃɛkəɹz
# 751784   bʌtaɪɡɛsɪfjʊɹnɑtθɹoʊɪŋʌpɔɹɛnɪθɪŋ
# 735153    meɪbiːjuːʃʊdd̠ʒʌstɡoʊsiːwʌtsɹɔŋ
#
#                                                       Text  \
# 190240                            daddy needs two flashes.
# 342890                       should we show her that song?
# 293751                              lots of presents here.
# 817748             you don't know anything about broccoli?
# 25046                                    in my ska school.
# 1089846                       just pretend there's a door.
# 809100                      yeah what other kind of candy?
# 544467              and then we have to make the checkers.
# 751784   but i guess if you're not throwing up or anyth...
# 735153          maybe you should just go see what's wrong.
#
#                                IPA_boundary                          IPA_rule
# 190240                   dædiniːdztuːflæʃɪz                dædiniːdztuːflæʃɪz
# 342890                  ʃʊdwiːʃoʊhɜːðæ|tsɔŋ                ʃʊdwiːʃoʊhɜːðætsɔŋ
# 293751                   lɑtsʌvpɹɛzən|tshɪɹ                 lɑtsʌvpɹɛzəntshɪɹ
# 817748       juːdoʊn|tnoʊɛnɪθɪŋʌbaʊtbɹɑkəli     juːdoʊntnoʊɛnɪθɪŋʌbaʊtbɹɑkəli
# 25046                         ɪnmaɪskɑskuːl                     ɪnmaɪskɑskuːl
# 1089846              d̠ʒʌstpɹɪ|tɛndðɛɹzʌdɔɹ             d̠ʒʌstpɹɪtɛndðɛɹzʌdɔɹ
# 809100              jɛhwʌ|tʌðəɹkaɪndʌvkændi            jɛhwʌtʌðəɹkaɪndʌvkændi
# 544467         ændðɛnwiːhævtəmeɪkðət̠ʃɛkəɹz      ændðɛnwiːhævtəmeɪkðət̠ʃɛkəɹz
# 751784   bʌ|taɪɡɛsɪfjʊɹnɑtθɹoʊɪŋʌ|pɔɹɛnɪθɪŋ  bʌtaɪɡɛsɪfjʊɹnɑtθɹoʊɪŋʌpɔɹɛnɪθɪŋ
# 735153     meɪbiːjuːʃʊdd̠ʒʌstɡoʊsiːwʌ|tsɹɔŋ   meɪbiːjuːʃʊdd̠ʒʌstɡoʊsiːwʌtsɹɔŋ
#
# [10 rows x 25 columns]

# %%
import re

min_words = 5  # Minimum length for utterances

# ============================================================
# Load and Filter Dataset
# ============================================================
dataset = load_dataset("phonemetransformers/IPA-CHILDES", "EnglishNA", split="train")
df = dataset.to_pandas()

# Keep only target child utterances
if "speaker_role" in df.columns:
    df = df[df["speaker_role"].str.lower().eq("target_child")]
elif "is_child" in df.columns:
    df = df[df["is_child"] == True]

# Keep utterances with at least N words
df["word_count"] = df["processed_gloss"].str.split().apply(len)
df = df[df["word_count"] >= min_words]

# ============================================================
# Text Cleaning and Normalization
# ============================================================
def clean_ipa(text):
    if not isinstance(text, str):
        return ""
    # Remove WORD_BOUNDARY and extra whitespace
    text = re.sub(r"\bWORD_BOUNDARY\b", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower().strip()
    return text

df["IPA"] = df["ipa_transcription"].apply(clean_ipa)
df["Text"] = df["processed_gloss"].apply(clean_text)

# Drop missing or empty values
df = df[(df["IPA"] != "") & (df["Text"] != "")]
df = df.drop_duplicates(subset=["IPA", "Text"]).reset_index(drop=True)

# ============================================================
# Train / Validation Split
# ============================================================
df = df.sample(frac=1, random_state=42)
cut = int(0.9 * len(df))
train_df, valid_df = df.iloc[:cut], df.iloc[cut:]

# ============================================================
# Save for Fine-tuning
# ============================================================
train_path = os.path.join(output_dir, "child_train.tsv")
valid_path = os.path.join(output_dir, "child_valid.tsv")

train_df[["IPA", "Text"]].to_csv(train_path, sep="\t", index=False, header=False)
valid_df[["IPA", "Text"]].to_csv(valid_path, sep="\t", index=False, header=False)

print(f"✅ Cleaned and saved to {output_dir}")
print(f"Train size: {len(train_df)} | Valid size: {len(valid_df)}")
print(train_df.head(3))
# Out:
# ✅ Cleaned and saved to /content/drive/MyDrive/Capstone/Corpus/ipa_childes
# Train size: 165753 | Valid size: 18418
#                                           processed_gloss  \
# 72558   i said i saw a little caterpillar a little cat...
# 69206                              where is she gonna go?
# 123163            mommy make some make some butter on my.
#
#                                         ipa_transcription  \
# 72558   aɪ WORD_BOUNDARY s ɛ d WORD_BOUNDARY aɪ WORD_B...
# 69206   w ɛ ɹ WORD_BOUNDARY ɪ z WORD_BOUNDARY ʃ iː WOR...
# 123163  m ɑ m i WORD_BOUNDARY m eɪ k WORD_BOUNDARY s ʌ...
#
#                                 character_split_utterance  is_child       id  \
# 72558   i WORD_BOUNDARY s a i d WORD_BOUNDARY i WORD_B...      True   969197
# 69206   w h e r e WORD_BOUNDARY i s WORD_BOUNDARY s h ...      True  2095265
# 123163  m o m m y WORD_BOUNDARY m a k e WORD_BOUNDARY ...      True   656497
#
#                                                     gloss  \
# 72558   I said I saw a little caterpillar a little cat...
# 69206                               where is she gonna go
# 123163             mommy make some make some butter on my
#
#                                                      stem         type  \
# 72558   I say I see a little caterpillar a little cate...  declarative
# 69206                                  where be she go go     question
# 123163                  mommy make make some butter on my  declarative
#
#        language  num_morphemes  ...  target_child_age target_child_sex  \
# 72558       eng             15  ...         40.625064             male
# 69206       eng              8  ...         39.855028             male
# 123163      eng              7  ...         57.001170           female
#
#        collection_id  corpus_id speaker_id  target_child_id  transcript_id  \
# 72558              2         48       2539             2539           4805
# 69206              2         65       3531             3531           7920
# 123163             2         42       2206             2206           4142
#
#         word_count                                                IPA  \
# 72558           13  aɪ s ɛ d aɪ s ɔ ʌ l ɪ t ə l k æ t ə ɹ p ɪ l ə ...
# 69206            5                        w ɛ ɹ ɪ z ʃ iː ɡ ə n ə ɡ oʊ
# 123163           8  m ɑ m i m eɪ k s ʌ m m eɪ k s ʌ m b ʌ t ə ɹ ɹ ...
#
#                                                      Text
# 72558   i said i saw a little caterpillar a little cat...
# 69206                              where is she gonna go?
# 123163            mommy make some make some butter on my.
#
# [3 rows x 23 columns]

# %%
# ============================================================
# Preview 100 Random IPA/Text Pairs
# ============================================================
preview_df = df.sample(n=100, random_state=123).reset_index(drop=True)

# Show in Colab (first 20 rows displayed automatically)
pd.set_option('display.max_colwidth', None)
display(preview_df[["IPA", "Text"]].head(20))

# Optionally, save the preview for manual review
preview_path = os.path.join(output_dir, "child_preview.tsv")
preview_df[["IPA", "Text"]].to_csv(preview_path, sep="\t", index=False)

print(f"✅ Preview of 100 samples saved to: {preview_path}")
# Out:
#                                                                                                                                            IPA  \
# 0                                                                                                     w aɪ j uː s ə p oʊ z d t ə p ʊ t ɪ t ɪ n
# 1                                                                                                 ɑ ɹ j uː t ɹ aɪ ɪ ŋ t ə h ɪ ɹ w ʌ t aɪ s ɛ d
# 2                                                                                                  aɪ d ɪ d n t w ɛ ɹ ɪ t ɪ n s k uː l d æ d i
# 3                                                                                                j ɛ h m ɑ m i d uː w iː ɡ ɑ t ɛ n i k æ n d i
# 4                                                                                                 aɪ ɡ ɑ t t ə k ʌ v ə ɹ m aɪ m aɪ b ɪ l d ɪ ŋ
# 5                                                                                 aɪ ɡ oʊ ɪ ŋ ɡ ɹ oʊ s ə ɹ ɹ i s t ɔ ɹ b aɪ s ʌ m m ɔ ɹ f uː d
# 6                                                                              æ n d æ n d m aɪ f aɪ ə ɹ ɹ ɛ n d̠ʒ ɪ n ɪ z s t ʌ k ɔ n d ɛ ɹ ə
# 7                                                                                  h ɪ ɹ z d ə ʌ ð ə ɹ k ɑ ɹ z k ʌ m ɪ ŋ ɪ n d ə k ɑ ɹ ɹ æ l i
# 8                                                                                                    ʌ n oʊ j uː d ɪ d n t iː v ə n t ɛ l m iː
# 9                                                                         ð ɪ s aɪ w ɔ n ə aɪ d oʊ n t w ɔ n ə s iː m ɪ s t ə ɹ w oʊ d̠ʒ ə ɹ z
# 10                                                                                                         aɪ m ɡ ə n ə ʃ oʊ j uː m aɪ t ɹ ʌ k
# 11                                                                                                 ɪ t ɪ t s ʌ s n eɪ k ð æ t iː t s ʌ m ɛ ɡ z
# 12                                                    h iː h ɑ p t ʌ w eɪ ð ɛ ɹ ð ɛ n h iː s ɔ h ɪ z m ɑ m i æ n d d æ d i w eɪ oʊ v ə ɹ ð ɛ ɹ
# 13                                                                                               w ʌ t h æ p ə n d t ə ð ɪ ɛ v ɹ ɪ θ ɪ ŋ ɛ l s
# 14  ɪ t ɡ oʊ ɪ ŋ ɪ t s ɡ oʊ ɪ ŋ ɪ n ð ɛ ɹ æ n d ɡ oʊ w uː ʃ æ n d ɡ oʊ w eɪ ɪ n ð ɛ ɹ æ n d ɡ oʊ aʊ t ð ɪ s d ɔ ɹ æ n d ɡ oʊ ɪ n ð æ t t ɹ ʌ k
# 15                                                                                 æ n d ð ɛ n w iː k ʊ d ɡ oʊ w ɪ ð m aɪ d æ d i t ə ð ə z uː
# 16                                                                                          aɪ w ɔ n t b oʊ l ɛ n ɹ ɪ f ɹ ɪ d̠ʒ ə ɹ ɹ eɪ t ə ɹ
# 17                                                                         j ɛ h b ʌ t ð ə θ ɹ oʊ t k oʊ t t iː m eɪ k s m iː f iː l b ɛ t ə ɹ
# 18                                                                                                 h ɪ ɹ z j ʊ ɹ h ɑ ɹ d p iː s ɪ z p iː s ɪ z
# 19                                                                               n oʊ d ʌ b ə l j uː eɪ t̠ʃ d ʌ b ə l j uː eɪ t̠ʃ w ɛ ɹ z m aɪ
#
#                                                                                                          Text
# 0                                                                              why you supposed to put it in?
# 1                                                                         are you trying to hear what i said?
# 2                                                                           i didn't wear it in school daddy.
# 3                                                                             yeah mommy do we got any candy?
# 4                                                                              i got to cover my my building.
# 5                                                                   i going grocery store buy some more food.
# 6                                                                    and and my fire engine is stuck on dere.
# 7                                                                here's de other cars coming in de car rally.
# 8                                                                              uh no you didn't even tell me.
# 9                                                               this i wanna i don't wanna see mister wogers.
# 10                                                                               i'm gonna show you my truck.
# 11                                                                         it it's a snake that eats um eggs.
# 12                                       he hopped away there then he saw his mommy and daddy way over there.
# 13                                                                      what happened to the everything else?
# 14  it going it's going in there and go whoosh and go way in there and go out this door and go in that truck.
# 15                                                             and then we could go with my daddy to the zoo.
# 16                                                                                i want bowl n refrigerator.
# 17                                                         yeah but the throat coat tea makes me feel better.
# 18                                                                            here's your hard pieces pieces.
# 19                                                                                       no wh wh where's my.
# ✅ Preview of 100 samples saved to: /content/drive/MyDrive/Capstone/Corpus/ipa_childes/child_preview.tsv
